# %% [markdown]
# # DSIM Main Cookbook

# %% [markdown]
# Top level cookbook for SRL DSIM 2024 data wrangling.
#
# %matplotlib inline

# %%
# import general libraries
import os
import sys
print(sys.version)

#import numpy as np
#import pandas as pd
#import plotly.offline as pyo
# import matplotlib as mpl
# import requests

# install dtat from dtat-library
# https://github.jpl.nasa.gov/Europa-PESS/dtat-library

import pandas as pd
from copy import copy

import dtat
import dtat.plot as dtatplot
from dtat.dataconnectors.csvconnector import CSVConnector
from dtat.types import CustomizedTrace

import numpy as np

# filter out warning messages; comment this when debugging
import warnings
warnings.filterwarnings('ignore')

# import FPSA libraries
#import dtat.stacked as dtat

# %matplotlib inline

# Dev venue primary collection name
COLLECTION_NAME = "STATE_MANAGER_DEMO"
# Out:
# 3.13.7 (main, Aug 14 2025, 11:12:11) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
# Plot some data

#file_input = CSVConnector("files/sampledata.csv").get_data()
file_input = CSVConnector("/Users/gameraman/dev/dtat-library/docs/sampledata.csv").get_data()




fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    # y_vars = [["PWR_BUS_VOLTAGE_1"],["PWR_VOLTAGE_1"],["PWR_BATTERY_VOLTAGE_1"],["PWR_CURRENT_1"]], # this is the y variables to plot
    y_vars = [["Sample1"]],
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'Sample1': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='cadetblue',  # setting the marker color
                                )
                             }
    
    )  # the x variable to plot by defaults to SCET
fig.show()

# %%
fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["PWR_VOLTAGE_1"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'PWR_VOLTAGE_1': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkorange',  # setting the marker color
                                )
                             }
    )  # the x variable to plot by defaults to SCET
fig.show()

# %%
fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["PWR_BATTERY_VOLTAGE_1"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'PWR_BATTERY_VOLTAGE_1': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkslateblue',  # setting the marker color
                                )
                             }
    )  # the x variable to plot by defaults to SCET
fig.show()

# %%
fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["PWR_CURRENT_1"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'PWR_CURRENT_1': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkgreen',  # setting the marker color
                                )
                             }
    )  # the x variable to plot by defaults to SCET
fig.show()

# %% [markdown]
# ## Relay Data Samples

# %%
# file_input = CSVConnector("/Users/dan/dev/mission_data_store/data/dsim_oct_2024/MRO_M20_2024_270_02-M20-opaf.csv").get_data()

# print(file_input)

# %%
fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["TX_FRAME_COUNT"],["TX_PWR"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'TX_FRAME_COUNT': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkgreen',  # setting the marker color
                                )
                             ,
        'TX_PWR': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='blue',  # setting the marker color
                                )
                             }
    )  # the x variable to plot by defaults to SCET
fig.show()

# %%
file_input = CSVConnector("/Users/dan/dev/mission_data_store/data/dsim_oct_2024/by_hand_example.csv").get_data()


fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["TX_PWR"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'TX_PWR': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkgreen',  # setting the marker color
                                )

                             }
    )  # the x variable to plot by defaults to SCET
fig.show()

# %%
file_input = CSVConnector("/Users/dan/dev/mission_data_store/data/dsim_oct_2024/by_hand_example_2.csv").get_data()


fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["TX_PWR"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'TX_PWR': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkgreen',  # setting the marker color
                                )

                             }
    )  # the x variable to plot by defaults to SCET
fig.show()

# %% [markdown]
# # Data Management Samples

# %%
file_input = CSVConnector("/Users/dan/dev/mission_data_store/data/dsim_oct_2024/upl1.csv").get_data()


fig,c,m,t = dtatplot.make_stacked_graph( # make_stacked_graph is the primary plotting method
    file_input,  # this is the data that DTAT plots from
    y_vars = [["UPL_VC0_FRAMES"], ["UPL_VC1_FRAMES"], ["UPL_VC2_FRAMES"]],  # this is the y variables to plot
    customize_dict={ # by passing the CustomizedTrace in a dictionary with y variables as the keys, you can control more trace settings
        'UPL_VC0_FRAMES': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='darkgreen',  # setting the marker color
                                ),
        'UPL_VC0_FRAMES': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='blue',  # setting the marker color
                                ),
        'UPL_VC0_FRAMES': CustomizedTrace(
                                    #size=10,  # setting the marker size
                                    #symbol='triangle-down-open',  # setting the marker shape, any plotly option is valid
                                    color='red',  # setting the marker color
                                )

                             }
    )  # the x variable to plot by defaults to SCET
fig.show()
